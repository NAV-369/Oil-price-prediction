# %% [markdown]
# # This notebook contains:
# 	•	Data Loading
# 	•	Data Cleaning
# 	•	Data Exploration
# 	•	Visualization

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("../data/raw/BrentOilPrices.csv", parse_dates=["Date"], index_col="Date")

# Basic info
df.info()

# Handling missing values
df.dropna(inplace=True)

# Sorting and removing duplicates
df = df.sort_index()
df = df[~df.index.duplicated()]

# Save cleaned data
df.to_csv("../data/processed/BrentOilCleaned.csv")

# Plot data
plt.figure(figsize=(12,6))
plt.plot(df["Price"], label="Brent Oil Price", color="blue")
plt.title("Brent Oil Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# /var/folders/h5/cqk4jd793hzd58k1ssq6mkd40000gn/T/ipykernel_96022/1957359982.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("../data/raw/BrentOilPrices.csv", parse_dates=["Date"], index_col="Date")
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9011 entries, 1987-05-20 to 2022-11-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   9011 non-null   float64
# dtypes: float64(1)
# memory usage: 140.8 KB
